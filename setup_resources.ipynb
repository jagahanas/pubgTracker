# %% [markdown]
# # Set up the script

# %%
# %matplotlib notebook
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
import skimage.io

# %% [markdown]
# # import the game map

# %%
erangel = imread('resources/erangelmap.jpg')
erangel=erangel[:,425:1500]
erangel_gray=color.rgb2gray(erangel)

# %%
figure();
imshow(erangel_gray,cmap='gray')
imsave('resources/erangelmapSmallgray.jpg',erangel_gray)
imsave('resources/erangelmapSmall.jpg',erangel)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## extract the grid

# %%
edges = feature.canny(erangel_gray,sigma=1)
lines = probabilistic_hough_line(edges, threshold=10, line_length=5,
                                 line_gap=3)

# %%
hogvec, hogim = feature.hog(erangel_gray,visualise=True)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
figure();
imshow(edges * 0)
for line in lines:
    p0, p1 = line
    plot((p0[0], p1[0]), (p0[1], p1[1]))
# Out:
# <img src="data:image/png;base64,..." width="752">

# %% [markdown]
# # Import a few sample video frames

# %%
frame1=imread('resources/frames/sampleGPV2/00011.png')

# %%
figure(); 
imshow(frame1[530:-20,1080:-25])
# Out:
# <img src="data:image/png;base64,..." width="432">
